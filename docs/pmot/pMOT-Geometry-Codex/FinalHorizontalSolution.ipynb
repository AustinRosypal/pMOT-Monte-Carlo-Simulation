# %% [markdown]
# # Final Horizontal pMOT Geometry Solution
#
# This notebook regenerates the current horizontal-path solution.
#
# Assumptions:
#
# - glass cell at `45 deg` AOI
# - `AC508-080-C` achromats, `f = 80.3 mm`, on both sides
# - 1530 nm round-trip foci targeted at `-10 mm` and `+10 mm`
# - 12.7 mm 780 nm MOT/cat-eye overlay
# - no coil exclusion zone for horizontal paths; only the glass cell envelope is modeled as a hard object

# %%
from pathlib import Path
from IPython.display import Image, display
import importlib

import pmot_final_horizontal_solution as horizontal

# Reload so edits to the solution script are picked up when rerunning this notebook.
horizontal = importlib.reload(horizontal)

horizontal.main()

output_path = Path(horizontal.__file__).with_name("FinalHorizontalSolution_with_780.png")
display(Image(filename=str(output_path)))
