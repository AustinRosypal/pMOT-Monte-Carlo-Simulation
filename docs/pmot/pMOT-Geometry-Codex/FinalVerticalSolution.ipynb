# %% [markdown]
# # Final Vertical pMOT Geometry Solution
#
# This notebook regenerates the working left-injection vertical solution using `AC254-045-C` lenses on both sides.
#
# It prints the key mechanical and optical positions, saves the final PNG, and displays the plot inline.

# %%
from pathlib import Path
from IPython.display import Image, display
import importlib

import pmot_combined_mixed_lenses_geometry as geometry

# Reload so edits to the geometry script are picked up when rerunning this notebook.
geometry = importlib.reload(geometry)

geometry.main()

output_path = Path(geometry.__file__).with_name(
    "pmot_combined_mixed_lenses_geometry_l1_045_l2_045.png"
)
display(Image(filename=str(output_path)))
# Out:
# Left-injection geometry: L1 AC254-045-C, L2 AC254-045-C
# ----------------------------------------------------------------
# L1 principal plane               = -56.578 mm
# L1 optical BFL surface estimate  = -48.278 mm
# L1 focus-side mount end (WD+3)   = -45.810 mm
# L1 outer physical surface        = -57.810 mm
# L1 outer-to-optical-table gap    = 56.495 mm
# L1 nearest-edge coil margin      = 9.810 mm
#
# L2 principal plane               = 46.505 mm
# L2 optical BFL surface estimate  = 38.205 mm
# L2 cell-side physical surface    = 43.756 mm
# L2 focus-side mount end (WD+3)   = 55.756 mm
# L2 nearest-edge coil margin      = 7.756 mm
# L1/L2 WD+3 used                  = 35.800 / 35.800 mm
#
# Shared mirror / 780 cateye       = 91.556 mm
# Mirror to L2 principal           = 45.050 mm
# 1530 focus 1                     = -10.010 mm
# 1530 focus 2                     = 10.010 mm
# 780 cateye focus                 = 91.556 mm
#
# ...
